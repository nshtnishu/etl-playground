-- %% [markdown]
-- ## Create Table

-- %%
show schemas;

-- %%
create schema batch_1.star_schema;

-- %%
CREATE TABLE IF NOT EXISTS batch_1.practice.customers (
    customer_id INT,
    name VARCHAR(50),
    country VARCHAR(50),
    signup_date DATE
    
    
);

-- %%
show tables in batch_1.practice;

-- %%
INSERT INTO batch_1.practice.customers
VALUES (1, 'John Smith', 'UK', DATE '2024-01-10'), (2, 'Nish', 'US', DATE '2024-01-31')

-- %%
INSERT INTO batch_1.practice.customers
VALUES (1, 'Smith', 'UK', DATE '2024-01-20'), (2, 'paul', 'US', DATE '2024-03-12'), (3, 'oliver', 'UAE', DATE '2025-04-14')

-- %%
SELECT *
FROM batch_1.practice.customers

-- %%
SELECT*FROM  batch_1.practice.customers;
select name, country, signup_date FROM batch_1.practice.customers;

-- %%
DESCRIBE batch_1.practice.customers;

-- %%
SELECT*FROM  batch_1.practice.customers where country= 'US';

-- %%
SELECT*FROM  batch_1.practice.customers;

-- %%
SELECT*FROM  batch_1.practice.customers where country= 'UK';

-- %%
select name FROM batch_1.practice.customers;

-- %%
UPDATE batch_1.practice.customers
SET country='USA'
WHERE customer_id=1;

-- %%
SELECT*FROM  batch_1.practice.customers;

-- %%
UPDATE  batch_1.practice.customers
SET country='India' WHERE customer_id=2;

-- %%
SELECT*FROM  batch_1.practice.customers;

-- %%
SELECT * FROM batch_1.practice.customers ORDER BY customer_id;

-- %%
SELECT customer_id, COUNT(*) AS cnt FROM batch_1.practice.customers GROUP BY customer_id;

-- %%
SELECT *
FROM batch_1.practice.customers
WHERE customer_id = 1;

-- %%
DELETE FROM batch_1.practice.customers
WHERE customer_id=1;

-- %%
SELECT * FROM batch_1.practice.customers;

-- %%
UPDATE batch_1.practice.customers
SET customer_id = 1
WHERE name = 'Nish';

-- %%
INSERT INTO batch_1.practice.customers
VALUES
(4, 'Juliana', 'UK', '2024-06-20'),
(5, 'Tarell', 'US', '2024-06-20');
UPDATE batch_1.practice.customers
SET country = 'USA'
WHERE name = 'paul';
UPDATE batch_1.practice.customers
SET country = 'USA'
WHERE name = 'paul';
UPDATE batch_1.practice.customers
SET country = 'UAE'
WHERE name = 'oliver';
SELECT *
FROM batch_1.practice.customers
ORDER BY customer_id;

-- %%
delete from batch_1.practice.customers where name='paul';
SELECT *
FROM batch_1.practice.customers
ORDER BY customer_id;

-- %%
delete from batch_1.practice.customers where country='US';
SELECT *
FROM batch_1.practice.customers
ORDER BY customer_id;

-- %% [markdown]
-- ## started the task again

-- %%
CREATE TABLE customers (
    customer_id INT,
    name VARCHAR(50),
    country VARCHAR(50),
    signup_date DATE
    
    
);

-- %%
INSERT INTO customers 
(customer_id, name, country, signup_date)
VALUES 
(1,'John Smith','UK','2024-01-10');

-- %%
INSERT INTO customers
(customer_id, name, country, signup_date)
VALUES
(2, 'Alice Brown', 'USA', '2024-02-15'),
(3, 'Raj Patel', 'India', '2024-03-01'),
(4, 'Emma Wilson', 'UK', '2024-04-01'),
(5, 'Emily Johnson', 'UAE', '2024-08-06'),
(6, 'Jayden Sidhu', 'India', '2024-11-21');

-- %%
select * from customers;

-- %%
INSERT INTO customers
(customer_id, name, country, signup_date)
VALUES
(7, 'Carlos Garcia', 'Spain', '2025-01-15'),
(8, 'Yuki Tanaka', 'Japan', '2025-02-20');

-- %%
select * from customers;

-- %%
SELECT customer_id, name
FROM customers;

-- %%
SELECT * FROM customers
WHERE country='UK';

-- %%
select * from customers;

-- %%
SELECT name
FROM customers;

-- %%
select * from customers;

-- %%
UPDATE customers
SET country='USA'
WHERE customer_id=1;

-- %%
select * from customers;

-- %%
UPDATE customers
SET country='Belgium'
WHERE name= 'Emma Wilson';

-- %%
select * from customers;

-- %%
UPDATE customers
SET country =
    CASE
        WHEN customer_id = 1 THEN 'USA'
        WHEN customer_id = 3 THEN 'UAE'
        WHEN customer_id = 5 THEN 'Canada'
        ELSE country
    END
WHERE customer_id IN (1, 3, 5);

-- %%
select * from customers;

-- %%
DELETE FROM customers
WHERE customer_id=1;

-- %%
select * from customers;

-- %%
DELETE FROM customers
WHERE country IN ('USA', 'Canada');

-- %%
select * from customers;
